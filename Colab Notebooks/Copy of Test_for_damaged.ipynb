# %%
import os
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd "gdrive/My Drive/Colab Notebooks"
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/Colab Notebooks'
# /content

# %%
# !pip install import-ipynb
import import_ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.6 MB 28.3 MB/s
# ...

# %%
from ipynb.fs.full.Car_damaged_or_not.ipynb import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-cea1cf68d6c1> in <module>
# ----> 1 from ipynb.fs.full.Car_damaged_or_not.ipynb import *
#
# ModuleNotFoundError: No module named 'ipynb'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
